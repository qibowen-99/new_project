# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://harimanoj4321:Manojhari@mlopscluster.unkj1nd.mongodb.net/?retryWrites=true&w=majority&appName=mlopscluster"
# Create a new client and connect to the server
client = MongoClient(uri)
import pandas as pd 
import json

class mongo_crud_operations:
    def __init__(self, client_url: str, database_name:str=None, collection_name:str=None):
        self.client_url = client_url
        self.database_name = database_name
        self.collection_name = collection_name
        
    def create_client(self):
        client = MongoClient(self.client_url)
        return client
    
    def create_database(self):
        client = self.create_client()
        db = client[self.database_name]
        return db
    
    def create_collection(self):
        db = self.create_database()
        collection = db[self.collection_name]
        return collection
    def insert_record(self, collection_name:str, data):
        if type(data) == list:
            for d in data:
                if type(d) != dict:
                    raise ValueError("Data should be in dictionary format")
            collection = self.create_collection()
            collection.insert_many(data)
            
        elif type(data) == dict:
            collection = self.create_collection()
            collection.insert_one(data)
                
        else:
            raise ValueError("Data should be in dictionary format")
        
    def find_all_records(self, collection_name:str):
        records = list(collection_name.find())
        for r in records:
            print(r)
    
    def find_record(self, collection_name:str, query:dict):
        records = list(collection_name.find(query))
        for r in records:
            print(r)
    def insert_in_bulk(self, datafile:str, collection_name:str):
        self.path = datafile
        
        if self.path.endswith(".json"):
            with open(self.path, "r") as file:
                data = json.load(file)
                
        elif self.path.endswith(".csv"):
            data = pd.read_csv(self.path, encoding='utf-8')
        
        elif self.path.endswith(".xlsx"):
            data = pd.read_excel(self.path, encoding='utf-8')
            
                
        datajson = json.loads(data.to_json(orient='records'))
        collection = self.create_collection(collection_name)
        collection.insert_many(datajson)


client_url = "mongodb+srv://harimanoj4321:Manojhari@mlopscluster.unkj1nd.mongodb.net/?retryWrites=true&w=majority&appName=mlopscluster"
database = "mynewdatabase"
collection_name = "myoldcolumn"
mongo=mongo_crud_operations(client_url,database,collection_name)
from pymongo import MongoClient

# Replace with your connection URI
uri = "mongodb+srv://harimanoj4321:Manojhari@mlopscluster.unkj1nd.mongodb.net/youtubecommunity?retryWrites=true&w=majority&appName=mlopscluster"
client = MongoClient(uri)

# Test connection
try:
    client.admin.command('ping')
    print("Connection successful!")
except Exception as e:
    print(f"Connection failed: {e}")

mongo.insert_record({"name":"sunny","designation":"data scientist","salary":"10k"},collection_name)
mongo.insert_record([{"name":"sunny","designation":"data scientist","salary":"10k"},
{"name":"sudhanshu","designation":"sr. data scientist","salary":"150k"},
{"name":"krish","designation":"lead data scientist","salary":"70k"}
],collection_name)
# Out:
# Connection failed: ac-cl0qnxp-shard-00-01.unkj1nd.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),ac-cl0qnxp-shard-00-02.unkj1nd.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),ac-cl0qnxp-shard-00-00.unkj1nd.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 66d76c3cc1269eee53dc5106, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-cl0qnxp-shard-00-00.unkj1nd.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoRec
# ...
